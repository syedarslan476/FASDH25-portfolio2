# %% [markdown]
# # Using stanza for Named Entity Recognition (continued)

# %% [markdown]
# ## Installation
#
# Run the code cell below to install stanza:

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.1 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 33.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %% [markdown]
# ## Import library and download language model
#
# After installing it, we import stanza into our notebook.

# %%
import stanza
import os
import pandas as pd
import re

# %% [markdown]
# ## Cloning the repository

# %%
# !git clone https://github.com/syedarslan476/FASDH25-portfolio2.git
# Out:
# Cloning into 'FASDH25-portfolio2'...
# remote: Enumerating objects: 4396, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 4396 (delta 12), reused 11 (delta 8), pack-reused 4375 (from 2)
# Receiving objects: 100% (4396/4396), 17.79 MiB | 20.09 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# Download the language model:
stanza.download("en")
#took help from slides 11.1

# Create the pipeline, specifying the language:
nlp = stanza.Pipeline(lang="en", processors='tokenize,mwt,ner')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# =========================================
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | ner       | ontonotes-ww-multi_charlm |
# =========================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %% [markdown]
# Filtering articles from January 2024

# %%
import os

# Set the folder path
folder = "/content/FASDH25-portfolio2/articles"

# List all files and filter only January 2024 articles
files = os.listdir(folder)
jan_files = [file for file in files if file.startswith("2024-01-") and file.endswith(".txt")]

# Show how many January articles were found
print("January files found:", len(jan_files))

# Create an empty dictionary to hold the places and their frequencies
places = {}
# Took some help from presentaion 9.2
# Loop through all the January files
for filename in jan_files:
    # Create the path to the file
    path = f"{folder}/{filename}"
    # Open and read the file
    with open(path, encoding="utf-8") as file:
        text = file.read()
        # Use the NLP pipeline to analyze the text
        doc = nlp(text)
        # Select only entities that are place names
        for e in doc.entities:
            if e.type in ["GPE", "LOC"]:
                # Add 1 to the count of the place in the dictionary
                places[e.text] = places.get(e.text, 0) + 1

# Print the resulting places dictionary
print(places)
# Out:
# January files found: 326
# {'Morocco': 13, 'Israel': 1593, 'Gaza': 1605, 'Rabat': 3, 'United States': 40, 'the United Arab Emirates': 13, 'UAE': 7, 'Bahrain': 11, 'Sudan': 3, 'US': 706, 'Western Sahara': 3, 'Washington': 60, 'Tel Aviv': 49, 'Algeria': 7, 'Marrakesh': 1, 'the Western Sahara': 1, 'Morocco’s': 1, 'Maghreb': 1, 'Ukraine': 47, 'Saudi Arabia': 39, 'California': 3, 'West Bank': 120, 'Dena': 1, 'Israel’s': 31, 'Oakland': 1, 'the United States': 97, 'South Africa': 200, 'Jordan': 42, 'Jerusalem': 26, 'East Jerusalem': 23, 'Egypt': 43, 'Qatar': 64, 'Kuala Lumpur': 4, 'Malaysia': 8, 'Palestine': 124, 'Indonesia’s': 1, 'Jakarta': 2, 'Johannesburg': 4, 'London': 17, 'Paris': 8, 'Vienna': 1, 'Berlin': 5, 'Amman': 6, 'Washington DC': 3, 'UK': 95, 'Manchester': 1, 'Yemen': 182, 'Washington, DC': 4, 'India': 50, 'Hyderabad': 1, 'Colombo’s Kollupitiya': 1, 'Namibia': 10, 'Germany': 31, 'Palestinian Territories': 1, 'Sweden': 2, 'Iran': 206, 'Kerman': 6, 'Lebanon': 175, 'Bethlehem': 4, 'Nairoukh': 1, 'China': 28, 'Italy': 10, 'Spain': 7, 'Turkey': 25, 'Shawawra': 1, 'The Hague': 33, 'South Africa’s': 8, 'the Gaza Strip': 123, 'Khan Younis': 23, 'Syria': 83, 'Mazzeh': 2, 'Damascus': 17, 'U.S.': 11, 'Houthis’': 3, 'the Red Sea': 194, 'the Bab-el-Mandeb Strait': 1, 'the Gulf of Aden': 23, 'Sanaa': 15, 'the United Kingdom': 28, 'Hodeidah': 5, 'Taiz': 2, 'Dhamar': 1, 'al-Bayda': 1, 'Saada': 3, 'the Arabian Sea': 6, 'the Bab al-Mandeb Strait': 5, 'Asia': 18, 'Europe': 30, 'Kuwait': 2, 'Middle East': 25, 'Ankara': 7, 'Red Sea': 50, 'United Kingdom': 12, 'West': 24, 'Tehran': 25, 'the Middle East': 77, 'South Carolina': 4, 'New York City': 1, 'Gaza’s': 18, 'Gaza City': 31, 'Rafah': 40, 'Gaza Strip': 31, 'Strip': 14, 'Istanbul': 2, 'Greece': 8, 'Crete': 2, 'Washington’s': 2, "Sweden's": 1, 'Iraq': 62, 'Gulf': 10, 'al-Dabshah': 1, 'Khirbet Selm': 1, 'Bint Jbeil': 1, 'Beirut': 84, 'Ibil El Saqi': 1, 'al-Tawil’s': 1, 'al-Khader': 1, 'the Bekaa Valley': 1, 'the Litani River': 1, 'Netherlands': 14, 'Malta': 2, 'the Gulf of Oman': 2, 'Davos': 7, 'Switzerland': 9, 'Deir el-Balah': 14, 'Maghazi': 5, 'Nuseirat': 11, 'Manchester City': 1, 'Barcelona': 1, 'Bab el-Mandeb strait': 1, 'Djibouti': 4, 'Southern Red Sea': 1, 'Africa’s Cape of Good Hope': 1, 'al-Shifa': 2, 'The United States': 21, 'Gretna': 2, 'Louisiana': 3, 'New Orleans': 5, 'the West Bank': 40, '@MirandaCleland': 1, 'France': 13, 'the Strip': 1, '@majedalansari': 1, 'Kan': 1, 'al-Mawasi district': 2, 'Mediterranean': 11, 'Africa': 29, 'Jenin': 19, 'Thameen Darby': 1, 'the Nakba Layer': 1, 'Russia': 43, 'Canada': 42, 'Mercator': 1, 'Alaska': 1, 'Mexico': 5, 'South America': 2, 'the Asia-Pacific': 1, 'Golan Heights': 1, 'The Golan Heights': 1, 'Crimea': 4, 'the South China Sea': 1, 'South China Sea': 1, 'Philippines': 4, 'Vietnam': 1, 'Pakistan': 24, 'Kashmir': 4, 'New Delhi': 6, 'Islamabad': 3, 'Darby’s Nakba': 1, 'the State of Israel': 7, 'Hebron': 10, 'Lama Khater': 1, 'Kiryat Arba': 2, 'Bureij': 2, 'al-Mahatta': 1, 'Belgium': 15, 'al-Mazra’a': 1, 'the Mediterranean Sea': 2, 'Ajaq': 1, 'Silwad': 1, 'Cairo': 6, 'Yemen’s': 6, 'Australia': 12, 'Denmark': 3, 'New Zealand': 2, 'South Korea': 1, 'Norway': 11, 'Hamas’s': 6, 'Yaroun': 3, 'Lebanon’s Nabatieh': 1, 'Yir’on': 1, 'Avivim': 1, 'Israel’s Goren': 1, 'Shatila': 3, 'Dahiyeh': 6, 'DC': 14, 'Doha': 19, 'Lisbon': 1, 'Portugal': 3, 'Walla': 2, 'Somalia': 1, 'Yemen’s Red Sea': 1, 'Gulf of Aden': 4, 'Yemen’s coast': 2, 'Lebanon’s': 3, 'Seychelles': 1, 'Bab al-Mandeb strait': 3, 'North Africa': 5, 'Marib': 3, 'the Gaza strip': 1, 'Gaza Strip’s': 3, 'Khreis’s': 1, 'Northern Gaza': 1, 'Hong Kong': 2, 'the State of Palestine': 1, 'Bolivia': 4, 'Bangladesh': 2, 'Comoros': 2, 'The United Kingdom': 3, 'Myanmar': 6, 'north📍#Gaza': 1, 'Erbil': 13, 'Pakistan’s Balochistan province': 2, 'Iran’s Sistan-Baluchestan province': 2, 'Iran’s': 3, 'Afghanistan': 7, 'Rask': 1, 'Sistan-Baluchestan': 1, 'the Strait of Hormuz': 3, 'the Persian Gulf': 1, 'Balochistan': 1, 'the Red Sea.': 1,  ...

# %% [markdown]
# ### Cleaning Places names

# %% [markdown]
# We can improve the readability by adding xml-style opening and closing tags (e.g., `<GPE>Rafah</GPE>`) instead of only a tag at the beginning of the entity. Adapt the code below so that it adds xml-style start and end tags:

# %%
import re
# Mostly took help from class presentation for the code
normalized_places = {}  # This will store cleaned place names with their total counts

# For standard naming conventions dictionary
# took help from Kulsoom
standard_names = {
    'gaza': 'Gaza',
    'u.s.': 'United States',
    'usa': 'United States',
    'uk': 'United Kingdom',
    'uae': 'United Arab Emirates',
    'britain': 'United Kingdom',
    'state of israel': 'Israel',
    'islamic republic of iran': 'Iran',
    'republic of yemen': 'Yemen',
    'state of palestine': 'Palestine',
    'beruit': 'Beirut',
    'dahiyeb': 'Dahiyeh',
    'tel israel': 'Tel Aviv',
    'westbank': 'West Bank',
    'gaza city': 'Gaza'
}
# Used presentation 9.2 for help
for place, count in places.items(): #took some help from chatgpt as well
    place = re.sub(r"[’'`]s\b", "", place)  # Remove possessive 's (like "Ali's Town" → "Ali Town")
    place = re.sub(r"[^\w\s]", "", place)   # Remove punctuation (like dots, commas, etc.)
    place = re.sub(r"^the\s+", "", place, flags=re.IGNORECASE)  # Remove 'The' at the beginning (case-insensitive)
    place = place.replace('\n', ' ')  # Convert newlines to spaces
    place = place.strip()  # Remove extra spaces

    # consider Gaza as a special case
    if re.search(r'gaza', place.lower()):
        normalized = standard_names['gaza']
    else:
        # Use the standardized name if available
        normalized = standard_names.get(place.lower(), place)

    # Add or update count for the normalized name
    if normalized in normalized_places:
        normalized_places[normalized] += count
    else:
        normalized_places[normalized] = count

# Show the final cleaned and combined place names with counts
print(normalized_places)
# Out:
# {'Morocco': 14, 'Israel': 1632, 'Gaza': 1830, 'Rabat': 3, 'United States': 162, 'United Arab Emirates': 21, 'Bahrain': 11, 'Sudan': 3, 'US': 717, 'Western Sahara': 4, 'Washington': 62, 'Tel Aviv': 52, 'Algeria': 7, 'Marrakesh': 1, 'Maghreb': 1, 'Ukraine': 47, 'Saudi Arabia': 39, 'California': 3, 'West Bank': 164, 'Dena': 1, 'Oakland': 1, 'South Africa': 208, 'Jordan': 43, 'Jerusalem': 26, 'East Jerusalem': 23, 'Egypt': 44, 'Qatar': 65, 'Kuala Lumpur': 4, 'Malaysia': 8, 'Palestine': 125, 'Indonesia': 3, 'Jakarta': 2, 'Johannesburg': 4, 'London': 17, 'Paris': 8, 'Vienna': 1, 'Berlin': 5, 'Amman': 6, 'Washington DC': 7, 'United Kingdom': 152, 'Manchester': 1, 'Yemen': 189, 'India': 50, 'Hyderabad': 1, 'Colombo Kollupitiya': 1, 'Namibia': 10, 'Germany': 31, 'Palestinian Territories': 1, 'Sweden': 3, 'Iran': 210, 'Kerman': 6, 'Lebanon': 178, 'Bethlehem': 4, 'Nairoukh': 1, 'China': 30, 'Italy': 10, 'Spain': 7, 'Turkey': 25, 'Shawawra': 1, 'Hague': 39, 'Khan Younis': 23, 'Syria': 84, 'Mazzeh': 2, 'Damascus': 17, 'Houthis': 3, 'Red Sea': 250, 'BabelMandeb Strait': 1, 'Gulf of Aden': 27, 'Sanaa': 15, 'Hodeidah': 5, 'Taiz': 2, 'Dhamar': 1, 'alBayda': 1, 'Saada': 3, 'Arabian Sea': 6, 'Bab alMandeb Strait': 9, 'Asia': 18, 'Europe': 30, 'Kuwait': 2, 'Middle East': 102, 'Ankara': 7, 'West': 24, 'Tehran': 25, 'South Carolina': 4, 'New York City': 1, 'Rafah': 40, 'Strip': 15, 'Istanbul': 2, 'Greece': 8, 'Crete': 2, 'Iraq': 64, 'Gulf': 10, 'alDabshah': 1, 'Khirbet Selm': 1, 'Bint Jbeil': 1, 'Beirut': 88, 'Ibil El Saqi': 1, 'alTawil': 1, 'alKhader': 1, 'Bekaa Valley': 1, 'Litani River': 1, 'Netherlands': 14, 'Malta': 2, 'Gulf of Oman': 2, 'Davos': 7, 'Switzerland': 9, 'Deir elBalah': 14, 'Maghazi': 5, 'Nuseirat': 11, 'Manchester City': 1, 'Barcelona': 1, 'Bab elMandeb strait': 1, 'Djibouti': 4, 'Southern Red Sea': 1, 'Africa Cape of Good Hope': 1, 'alShifa': 2, 'Gretna': 2, 'Louisiana': 3, 'New Orleans': 5, 'MirandaCleland': 1, 'France': 14, 'majedalansari': 1, 'Kan': 1, 'alMawasi district': 2, 'Mediterranean': 12, 'Africa': 29, 'Jenin': 19, 'Thameen Darby': 1, 'Nakba Layer': 1, 'Russia': 43, 'Canada': 42, 'Mercator': 1, 'Alaska': 1, 'Mexico': 5, 'South America': 2, 'AsiaPacific': 1, 'Golan Heights': 3, 'Crimea': 4, 'South China Sea': 2, 'Philippines': 4, 'Vietnam': 1, 'Pakistan': 24, 'Kashmir': 4, 'New Delhi': 6, 'Islamabad': 3, 'Darby Nakba': 1, 'Hebron': 10, 'Lama Khater': 1, 'Kiryat Arba': 2, 'Bureij': 2, 'alMahatta': 1, 'Belgium': 16, 'alMazraa': 1, 'Mediterranean Sea': 2, 'Ajaq': 1, 'Silwad': 1, 'Cairo': 6, 'Australia': 13, 'Denmark': 3, 'New Zealand': 2, 'South Korea': 1, 'Norway': 11, 'Hamas': 6, 'Yaroun': 3, 'Lebanon Nabatieh': 1, 'Yiron': 1, 'Avivim': 1, 'Israel Goren': 1, 'Shatila': 3, 'Dahiyeh': 7, 'DC': 14, 'Doha': 19, 'Lisbon': 1, 'Portugal': 3, 'Walla': 2, 'Somalia': 1, 'Yemen Red Sea': 1, 'Yemen coast': 2, 'Seychelles': 1, 'Bab alMandeb strait': 3, 'North Africa': 5, 'Marib': 3, 'Khreis': 1, 'Hong Kong': 2, 'Bolivia': 4, 'Bangladesh': 2, 'Comoros': 2, 'Myanmar': 6, 'Erbil': 13, 'Pakistan Balochistan province': 2, 'Iran SistanBaluchestan province': 2, 'Afghanistan': 7, 'Rask': 1, 'SistanBaluchestan': 1, 'Strait of Hormuz': 3, 'Persian Gulf': 1, 'Balochistan': 1, 'La France': 1, 'Entebbe': 1, 'Uganda': 12, 'Montreal': 1, 'Milton Ontario': 1, 'Jabalia': 11, 'Ottawa': 3, 'Toronto': 1, 'Calgary': 1, 'New York': 4, 'Belarus': 1, 'Munich': 2, 'Haifa': 8, 'Sidon': 3, 'Salameh': 1, 'alMughraqa': 1, 'alMaghazi': 1, 'Maghazi Roads': 1, 'Deir alBalah': 1, 'Islamic Republic': 5, 'Nur Shams': 1, 'Tulkarem': 2, 'Naqoura': 2, 'America': 4, 'El Arish': 3, 'Al Jazeera': 1, 'alMawasi': 3, 'Beirut Shatila': 1, 'AlFukhari': 1, 'Zeitoun': 4, 'alFukhari': 2, 'Hajjah': 2, 'Ramallah': 24, 'Abwein': 1, 'Nablus': 5, 'Qalqilya': 2, 'Jericho': 1, 'Ein alHilweh': 1, 'Basel': 3, 'Ofer': 1, 'Jordan Valley': 5, 'Area C': 6, 'Kadri': 1, 'alJiftlik': 1, 'Farsiya': 1, 'Makhoul': 1, 'Tubas': 1, 'Areas A': 1, 'Japan': 9, 'Silicon Valley': 3, 'Netanyahu': 7, 'West Je ...

# %% [markdown]
# We could come up with ways to fix errors like these.
#
# One option would be to create a dictionary of known errors,
# so that when we loop through the entities, we can fix them:

# %% [markdown]
# ### Storing data in a tsv file
#
# We can now store the counts in a tsv file, so we can reuse it in a different script.
#
# Let's create a tsv file with two columns: "name" and "frequency".
# We'll create the tsv file in two steps:
#
# 1. we create the header: that is, the column names, separated by tabs
# 2. we loop through all the place names, and we create a new row in the table for each place. Each row will contain the place name and its frequency, separated by a tab. Each row will have to start on a new line, so we'll also have to add a newline character \n to the row; should we add it at the beginning or end of the line, or both?
#
# Fill in the blanks:

# %%
filename = "ner_counts.tsv"
# open the file in writing mode and with unicode UTF-8 encoding:
with open("ner_counts.tsv", mode= "w", encoding= "utf-8") as file:
  # create a header of the tsv files, which consists of the column names separated by a tab:
  header = "Place\tCount\n"
  # write the header to the file:
  file.write(header)
  # Now, loop through the places dictionary and create a new row for each item in the dictionary
  for place, count in normalized_places.items():
    row = f"{place}\t{count}\n"
    # finally, write the row to the file:
    file.write(row)

# %% [markdown]
# The file will now be stored in our colab's session environment. You can see it by clicking the folder icon in the left-hand tool bar in colab. Double-click it to view it in colab. Right-click it and choose "Download" to download the file.
#
# To access it in your script, use the path `/content/ner_counts.tsv`

# %%
with open("/content/ner_counts.tsv", encoding="utf-8") as file:
  print(file.read())
# Out:
# Place	Count
# Morocco	14
# Israel	1632
# Gaza	1830
# Rabat	3
# United States	162
# United Arab Emirates	21
# Bahrain	11
# Sudan	3
# US	717
# Western Sahara	4
# Washington	62
# Tel Aviv	52
# Algeria	7
# Marrakesh	1
# Maghreb	1
# Ukraine	47
# Saudi Arabia	39
# California	3
# West Bank	164
# Dena	1
# Oakland	1
# South Africa	208
# Jordan	43
# Jerusalem	26
# East Jerusalem	23
# Egypt	44
# Qatar	65
# Kuala Lumpur	4
# Malaysia	8
# Palestine	125
# Indonesia	3
# Jakarta	2
# Johannesburg	4
# London	17
# Paris	8
# Vienna	1
# Berlin	5
# Amman	6
# Washington DC	7
# United Kingdom	152
# Manchester	1
# Yemen	189
# India	50
# Hyderabad	1
# Colombo Kollupitiya	1
# Namibia	10
# Germany	31
# Palestinian Territories	1
# Sweden	3
# Iran	210
# Kerman	6
# Lebanon	178
# Bethlehem	4
# Nairoukh	1
# China	30
# Italy	10
# Spain	7
# Turkey	25
# Shawawra	1
# Hague	39
# Khan Younis	23
# Syria	84
# Mazzeh	2
# Damascus	17
# Houthis	3
# Red Sea	250
# BabelMandeb Strait	1
# Gulf of Aden	27
# Sanaa	15
# Hodeidah	5
# Taiz	2
# Dhamar	1
# alBayda	1
# Saada	3
# Arabian Sea	6
# Bab alMandeb Strait	9
# Asia	18
# Europe	30
# Kuwait	2
# Middle East	102
# Ankara	7
# West	24
# Tehran	25
# South Carolina	4
# New York City	1
# Rafah	40
# Strip	15
# Istanbul	2
# Greece	8
# Crete	2
# Iraq	64
# Gulf	10
# alDabshah	1
# Khirbet Selm	1
# Bint Jbeil	1
# Beirut	88
# Ibil El Saqi	1
# alTawil	1
# alKhader	1
# Bekaa Valley	1
# Litani River	1
# Netherlands	14
# Malta	2
# Gulf of Oman	2
# Davos	7
# Switzerland	9
# Deir elBalah	14
# Maghazi	5
# Nuseirat	11
# Manchester City	1
# Barcelona	1
# Bab elMandeb strait	1
# Djibouti	4
# Southern Red Sea	1
# Africa Cape of Good Hope	1
# alShifa	2
# Gretna	2
# Louisiana	3
# New Orleans	5
# MirandaCleland	1
# France	14
# majedalansari	1
# Kan	1
# alMawasi district	2
# Mediterranean	12
# Africa	29
# Jenin	19
# Thameen Darby	1
# Nakba Layer	1
# Russia	43
# Canada	42
# Mercator	1
# Alaska	1
# Mexico	5
# South America	2
# AsiaPacific	1
# Golan Heights	3
# Crimea	4
# South China Sea	2
# Philippines	4
# Vietnam	1
# Pakistan	24
# Kashmir	4
# New Delhi	6
# Islamabad	3
# Darby Nakba	1
# Hebron	10
# Lama Khater	1
# Kiryat Arba	2
# Bureij	2
# alMahatta	1
# Belgium	16
# alMazraa	1
# Mediterranean Sea	2
# Ajaq	1
# Silwad	1
# Cairo	6
# Australia	13
# Denmark	3
# New Zealand	2
# South Korea	1
# Norway	11
# Hamas	6
# Yaroun	3
# Lebanon Nabatieh	1
# Yiron	1
# Avivim	1
# Israel Goren	1
# Shatila	3
# Dahiyeh	7
# DC	14
# Doha	19
# Lisbon	1
# Portugal	3
# Walla	2
# Somalia	1
# Yemen Red Sea	1
# Yemen coast	2
# Seychelles	1
# Bab alMandeb strait	3
# North Africa	5
# Marib	3
# Khreis	1
# Hong Kong	2
# Bolivia	4
# Bangladesh	2
# Comoros	2
# Myanmar	6
# Erbil	13
# Pakistan Balochistan province	2
# Iran SistanBaluchestan province	2
# Afghanistan	7
# Rask	1
# SistanBaluchestan	1
# Strait of Hormuz	3
# Persian Gulf	1
# Balochistan	1
# La France	1
# Entebbe	1
# Uganda	12
# Montreal	1
# Milton Ontario	1
# Jabalia	11
# Ottawa	3
# Toronto	1
# Calgary	1
# New York	4
# Belarus	1
# Munich	2
# Haifa	8
# Sidon	3
# Salameh	1
# alMughraqa	1
# alMaghazi	1
# Maghazi Roads	1
# Deir alBalah	1
# Islamic Republic	5
# Nur Shams	1
# Tulkarem	2
# Naqoura	2
# America	4
# El Arish	3
# Al Jazeera	1
# alMawasi	3
# Beirut Shatila	1
# AlFukhari	1
# Zeitoun	4
# alFukhari	2
# Hajjah	2
# Ramallah	24
# Abwein	1
# Nablus	5
# Qalqilya	2
# Jericho	1
# Ein alHilweh	1
# Basel	3
# Ofer	1
# Jordan Valley	5
# Area C	6
# Kadri	1
# alJiftlik	1
# Farsiya	1
# Makhoul	1
# Tubas	1
# Areas A	1
# Japan	9
# Silicon Valley	3
# Netanyahu	7
# West Jerusalem	1
# Brussels	5
# League of Arab States	1
# West Beirut	9
# Beirut Hamra	1
# Hamra	3
# West Beirutis	1
# Dabbouch	1
# East Beirut	1
# Austria	3
# Finland	3
# Iceland	1
# Romania	4
# Melbourne Australia	1
# Melbourne	5
# Sandridge Beach	1
# ZIM Ganges	5
# Sydney	1
# Brisbane	1
# Rawaa	1
# Middle East Eye	1
# Near East	3
# Kyiv	5
# Houthi	3
# Aqaba	1
# Marshall Islands	1
# Aden	3
# Sabra	1
# Farhana	1
# Abudaqa	2
# IsraelPalestine	2
# Shujayea	3
# Khan Yunis	1
# Mawasi	1
# Bosnia	3
# Sri Lanka	2
# Republic of South Africa	1
# Columbia	3
# Chile	5
# Santiago	1
# Taiz province	1
# AlBayda	1
# Ashdod	2
# Hebrew	1
# X Spain	1
# Madrid	1
# Oman	1
# Charleston	1
# Geneva	2
# AlAqsa	1
# Zawayda	1
# Beit Hanoon	1
# Serbia	3
# BosniaHerzegovina	1
# Srebrenica	1
# Bani Suheila	2
# Caesarea	2
# Kefar Sava	1
# Rehovot	1
# Beersheba	1
# Kiryat Shmona	1
# Blue Line	1
# Baghdad	8
# Middle Eastern	3
# Welch	1
# Global South	2
# NaksBilal	1
# Beit Lahiya	2
# El Amal City Hospital	1
# Maroun El Ras	1
# Rmeish	1
# Miraj	1
# Tal alHawa	1
# zarahsultana	1
# Gisha	1
# Bani Naim	1
# Raanana	1
# Sderot	2
# Nir Am	1
# Mefalsim	1
# Hanita	1
# Mattat	1
# Margaliot	1
# Adamit	1
# Zarit	1
# Malkia	1
# Herzegovina	1
# Montenegro	1
# Yugoslavia	2
# Moscow	4
# Pretoria	8
# Mozambique	1
# Bulgaria	1
# Shadi	1
# Ebel elSaqi	1
# Panjgur	1
# SistanBaluchestan province	1
# Ocean Jazz	1
# Cape of Good Hope	12
# alWalaja	5
# Gilo	1
# Har Gilo	1
# Singapore	2
# Ras Issa	1
# Hodeidah province	1
# Dearborn	12
# Michigan	12
# Mackinac Island	1
# Great Lakes	1
# Lake Michigan	1
# Texas	3
# Beit Nabala	1
# Idlib	3
# Riyadh	5
# Alborz	4
# Southern Africa	2
# Bab alMandeb	2
# Venezuela	1
# Hormuz	1
# Arabian Gulf	1
# Dublin	3
# Al Rayyan	1
# Cape Town	2
# South Africansfrom	1
# Africa4Palestine	1
# Western Cape province	1
# Chicago	2
# Cyprus	9
# Akrotiri	12
# Limassol	1
# Pashias	1
# Anadolu	1
# Nevatim	1
# Republic of Cyprus	2
# Dhekelia	1
# alSaftawi	1
# Detroit	1
# Southeast Michigan	1
# Arab America	1
# Jarrah	1
# Wayne County	1
# Minnesota	1
# Scotland	2
# Ireland	3
# October7	2
# Entebbe Uganda	1
# Sierra Leone	1
# DRC	1
# adoniaayebare	1
# Aroura	2
# alArouri	2
# Salem	1
# Copenhagen	1
# Tunisia	2
# Syria Aleppo	1
# Mariupol	1
# Indian Ocean	2
# Kanaker	1
# Sarit	1
# Aleppo	2
# alTanf	1
# Hashemite Kingdom of Jordan	1
# Jordan River	1
# Palestine_UN	1
# India Basmati	1
# North America	2
# Earth	1
# alAmal	4
# alNasser	1
# alKatiba	1
# Rohtak	6
# Haryana	3
# Uttar Pradesh	1
# Lucknow	1
# UP	1
# Bihar	4
# West Bengal	1
# Benarasiyaa	1
# Haryana Panipat	1
# Thailand	2
# Haryana Jind	1
# Al Maniya	1
# Bab al	1
# Mandeb Strait	1
# alMazraa Asharqiya	2
# Harvey	1
# Tawfiq	1
# Hamoud	1
# Taalbaya	1
# Rashidiya	1
# Karem Abu Salem	1
# Kerem Shalom	1
# Estonia	1
# Kampala	5
# Peru	1
# Colombia	1
# South Sudan	1
# Swaziland	1
# RedSea	1
# Bern	1
# Zurich	1
# Arura	2
# Hezbollah	1
# Deir Qaddis	1
# MoTaz	1
# azaizamotaz9	1
# Israel Haifa	1
# Dubai	1
# Yemen southern coast	1
# Egypt Sinai Peninsula	1
# Philadelphi	1
# Dahiya	1
# Jamaa Islamiya	2
# Cameroon	1
# alAhli	1
# Des Moines	7
# Iowa	12
# Cedar Rapids	5
# Iowa City	5
# South Asia	1
# Florida	1
# New York Ellis Island	1
# Ohio	1
# Czech Republic	1
# Hungary	1
# Slovenia	1
# carogennez	1
# Flanders	1
# Wallonia	1
# Supernova	1
# Syria Damascus	1
# Borj el Barajneh	1
# Libya	3
# Rwanda	1
# East Timor	1
# Kabul	1
# azZahra	1
# Hamad	1
# State of Qatar	1
# QFFD	1
# Aizawl	6
# Manipur	8
# Kangpokpi	1
# Mizoram	8
# Kingdom of Judah	1
# Bnei Menashe	3
# Kolasib	1
# Beit Shemesh	1
# Santa Clara	1
# Moldova	1
# Ansarallah	1
# Eurasia	1
# Heliopolis	1
# alFawakhir	1
# Levant	1
# Mecca	1
# AlMasjid alOmari alKabir	1
# Byzantium	1
# Via Maris	2
# Anthedon	1
# Balakhiyah	1
# Tida	1
# Tell elAjjul	1
# Calves Hill	1
# Daraj	1
# Ahmadiyyah Zawiya	1
# Eastern Mediterranean	1
# Netivot	1
# BabelMandeb strait	1
# Eilat	2
# Dead Sea	1
# Eastern Mediterranean region	1
# alKarama	1
# Paltel	1
# Jawwal	1
# Syria Golan Heights	1
# Kurdistan	1
# Panjgur Pakistan Balochistan province	1
# Bahaa elDin Abu Ras	1
# Dura	2
# Bahaa	1
# Maldives	1
# RepJayapal	1
# RepCori	1
# BasedMikeLee	1
# Republic of Korea	1
# Kosovo	1
# PA	1
# Oslo	2

# %% [markdown]
# # Geocoding
#
# Geocoding is the process of finding coordinates for a place.
#
# The process uses APIs, Application Programming Interfaces,
# which are internet services that are designed not for human reading
# but for being called by applications.
#
# There are many APIs that provide geocoding services. They typically have a database of place names and their coordinates. If you send a geocoding API a place name, it will return its coordinates (and perhaps some other data). Many of them are not free. In our case, we'll use the free GeoNames API to find our place names.
#
# First, try it out by pasting the following URL in your browser (make sure to replace `<your_user_name>` with your geonames user name:
#
# `http://api.geonames.org/searchJSON?q=Gaza&maxRows=5&username=<your_user_name>`
#
# Paste the response here:
#
# {"totalResultsCount":5276,"geonames":[{"adminCode1":"GZ","lng":"34.46672","geonameId":281133,"toponymName":"Gaza","countryId":"6254930","fcl":"P","population":410000,"countryCode":"PS","name":"Gaza","fclName":"city, village,...","adminCodes1":{},"countryName":"Palestine","fcodeName":"seat of a first-order administrative division","adminName1":"Gaza Strip","lat":"31.50161","fcode":"PPLA"},{"adminCode1":"GZ","lng":"34.48347","geonameId":281129,"toponymName":"Jabālyā","countryId":"6254930","fcl":"P","population":168568,"countryCode":"PS","name":"Jabalia","fclName":"city, village,...","adminCodes1":{},"countryName":"Palestine","fcodeName":"populated place","adminName1":"Gaza Strip","lat":"31.5272","fcode":"PPL"},{"adminCode1":"GZ","lng":"34.30627","geonameId":281124,"toponymName":"Khān Yūnis","countryId":"6254930","fcl":"P","population":173183,"countryCode":"PS","name":"Khan Yunis","fclName":"city, village,...","adminCodes1":{},"countryName":"Palestine","fcodeName":"seat of a second-order administrative division","adminName1":"Gaza Strip","lat":"31.34018","fcode":"PPLA2"},{"adminCode1":"02","lng":"33","geonameId":1046058,"toponymName":"Gaza Province","countryId":"1036973","fcl":"A","population":1422460,"countryCode":"MZ","name":"Gaza Province","fclName":"country, state, region,...","adminCodes1":{"ISO3166_2":"G"},"countryName":"Mozambique","fcodeName":"first-order administrative division","adminName1":"Gaza Province","lat":"-23.5","fcode":"ADM1"},{"adminCode1":"GZ","lng":"34.24357","geonameId":281102,"toponymName":"Rafaḩ","countryId":"6254930","fcl":"P","population":126305,"countryCode":"PS","name":"Rafah","fclName":"city, village,...","adminCodes1":{},"countryName":"Palestine","fcodeName":"seat of a second-order administrative division","adminName1":"Gaza Strip","lat":"31.29722","fcode":"PPLA2"}]}

# %% [markdown]
# I have created a function, `get_coordinates` that will take your a place name and your Geonames user name as an argument and return the coordinates. Please fill in your user name and run the code cell to make the function available:

# %%
import requests
import time
# used presentation slide 11.2
geonames_username = "abdus.salam2"

def get_coordinates(place, username=geonames_username, fuzzy=0, timeout=1):
  """This function gets a single set of coordinates from the geonames API.

  Args:
    place (str): the place name
    username (str): your geonames user name
    fuzzy (int): 0 = exact matching, 1 = fuzzy matching (allow similar but not exact matches)
    timeout (int): number of seconds to wait before a call to the geonames API
      (to avoid being blocked for overloading the server)

  Returns:
    dictionary: keys: latitude, longitude
  """
  # wait a short while, so that we don't overload the server:
  time.sleep(timeout)
  # make the API call:
  url = "http://api.geonames.org/searchJSON?"
  params = {"q": place, "username": username, "fuzzy": fuzzy, "maxRows": 1, "isNameRequired": True}
  response = requests.get(url, params=params)
  # convert the response into a dictionary:
  results = response.json()
  print(results)
  # get the first result:
  try:
    result = results["geonames"][0]
    return {"latitude": result["lat"], "longitude": result["lng"]}
  except (IndexError, KeyError):
    print("No results found for your API call", response.request.url)

# %%
# Input and output filenames
input_filename = "ner_counts.tsv"
output_filename = "ner_gazetteer.tsv"

# Read place names from ner_counts.tsv
with open(input_filename, "r", encoding="utf-8") as file:
    lines = file.readlines()

# Skip the header and extract place names
place_names = [line.strip().split("\t")[0] for line in lines[1:]]

# Write results to ner_gazetteer.tsv
with open(output_filename, "w", encoding="utf-8") as out_file:
    out_file.write("Name\tLatitude\tLongitude\n")

    for name in place_names:
        coordinates = get_coordinates(name)
        if coordinates:
            lat = coordinates['latitude']
            lon = coordinates['longitude']
            out_file.write(f"{name}\t{lat}\t{lon}\n")
        else:
            out_file.write(f"{name}\tNA\tNA\n")

# Display the file
with open(output_filename, encoding="utf-8") as file:
    print(file.read())
# Out:
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '-10', 'geonameId': 2542007, 'toponymName': 'Kingdom of Morocco', 'countryId': '2542007', 'fcl': 'A', 'population': 36029138, 'countryCode': 'MA', 'name': 'Morocco', 'fclName': 'country, state, region,...', 'countryName': 'Morocco', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '28.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '00', 'lng': '34.75', 'geonameId': 294640, 'toponymName': 'State of Israel', 'countryId': '294640', 'fcl': 'A', 'population': 8883800, 'countryCode': 'IL', 'name': 'Israel', 'fclName': 'country, state, region,...', 'countryName': 'Israel', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 96, 'geonames': [{'adminCode1': '04', 'lng': '-6.83255', 'geonameId': 2538475, 'toponymName': 'Rabat', 'countryId': '2542007', 'fcl': 'P', 'population': 1655753, 'countryCode': 'MA', 'name': 'Rabat', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '04'}, 'countryName': 'Morocco', 'fcodeName': 'capital of a political entity', 'adminName1': 'Rabat-Salé-Kénitra', 'lat': '34.01325', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 209, 'geonames': [{'adminCode1': '00', 'lng': '-98.5', 'geonameId': 6252001, 'toponymName': 'United States', 'countryId': '6252001', 'fcl': 'A', 'population': 327167434, 'countryCode': 'US', 'name': 'United States', 'fclName': 'country, state, region,...', 'countryName': 'United States', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39.76', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 531, 'geonames': [{'adminCode1': '00', 'lng': '54.5', 'geonameId': 290557, 'toponymName': 'United Arab Emirates', 'countryId': '290557', 'fcl': 'A', 'population': 9630959, 'countryCode': 'AE', 'name': 'United Arab Emirates', 'fclName': 'country, state, region,...', 'countryName': 'United Arab Emirates', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '23.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '50.55', 'geonameId': 290291, 'toponymName': 'Kingdom of Bahrain', 'countryId': '290291', 'fcl': 'A', 'population': 1569439, 'countryCode': 'BH', 'name': 'Bahrain', 'fclName': 'country, state, region,...', 'countryName': 'Bahrain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '26.03333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 36, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 366755, 'toponymName': 'Republic of the Sudan', 'countryId': '366755', 'fcl': 'A', 'population': 41801533, 'countryCode': 'SD', 'name': 'Sudan', 'fclName': 'country, state, region,...', 'countryName': 'Sudan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '16', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '11', 'lng': '1.96667', 'geonameId': 2971316, 'toponymName': 'Us', 'countryId': '3017382', 'fcl': 'P', 'population': 1248, 'countryCode': 'FR', 'name': 'Us', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'populated place', 'adminName1': 'Île-de-France', 'lat': '49.1', 'fcode': 'PPL'}]}
# {'totalResultsCount': 715, 'geonames': [{'adminCode1': '00', 'lng': '105.83224', 'geonameId': 11497302, 'toponymName': 'Western Region', 'countryId': '1562822', 'fcl': 'L', 'population': 17080000, 'countryCode': 'VN', 'name': 'Western Region', 'fclName': 'parks,area, ...', 'countryName': 'Vietnam', 'fcodeName': 'region', 'adminName1': '', 'lat': '10.01211', 'fcode': 'RGN'}]}
# {'totalResultsCount': 425, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 325, 'geonames': [{'adminCode1': '05', 'lng': '34.78057', 'geonameId': 293397, 'toponymName': 'Tel Aviv', 'countryId': '294640', 'fcl': 'P', 'population': 432892, 'countryCode': 'IL', 'name': 'Tel Aviv', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Tel Aviv', 'lat': '32.08088', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '3', 'geonameId': 2589581, 'toponymName': "People's Democratic Republic of Algeria", 'countryId': '2589581', 'fcl': 'A', 'population': 42228429, 'countryCode': 'DZ', 'name': 'Algeria', 'fclName': 'country, state, region,...', 'countryName': 'Algeria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '28', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '07', 'lng': '-7.99994', 'geonameId': 2542997, 'toponymName': 'Marrakesh', 'countryId': '2542007', 'fcl': 'P', 'population': 995871, 'countryCode': 'MA', 'name': 'Marrakesh', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '07'}, 'countryName': 'Morocco', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Marrakesh-Safi', 'lat': '31.63416', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 4, 'geonames': [{'lng': '5', 'geonameId': 2219875, 'name': 'Arab Maghreb', 'fclName': 'parks,area, ...', 'toponymName': 'Al Maghrib', 'fcodeName': 'region', 'adminName1': '', 'lat': '30', 'fcl': 'L', 'fcode': 'RGN', 'population': 76800000}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '32', 'geonameId': 690791, 'toponymName': 'Ukraine', 'countryId': '690791', 'fcl': 'A', 'population': 44622516, 'countryCode': 'UA', 'name': 'Ukraine', 'fclName': 'country, state, region,...', 'countryName': 'Ukraine', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '49', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 338, 'geonames': [{'adminCode1': 'CA', 'lng': '-119.75126', 'geonameId': 5332921, 'toponymName': 'California', 'countryId': '6252001', 'fcl': 'A', 'population': 39512223, 'countryCode': 'US', 'name': 'California', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'California', 'lat': '37.25022', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 2604, 'geonames': [{'adminCode1': '10375968', 'lng': '-81.39281', 'geonameId': 3580477, 'toponymName': 'West Bay', 'countryId': '3580718', 'fcl': 'P', 'population': 15335, 'countryCode': 'KY', 'name': 'West Bay', 'fclName': 'city, village,...', 'countryName': 'Cayman Islands', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'West Bay', 'lat': '19.38197', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '14', 'lng': '90.28327', 'geonameId': 10274676, 'toponymName': 'Dena', 'countryId': '1814991', 'fcl': 'L', 'population': 0, 'countryCode': 'CN', 'name': 'Dena', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'XZ'}, 'countryName': 'China', 'fcodeName': 'grazing area', 'adminName1': 'Tibet', 'lat': '28.44289', 'fcode': 'GRAZ'}]}
# {'totalResultsCount': 233, 'geonames': [{'adminCode1': 'CA', 'lng': '-122.2708', 'geonameId': 5378538, 'toponymName': 'Oakland', 'countryId': '6252001', 'fcl': 'P', 'population': 419267, 'countryCode': 'US', 'name': 'Oakland', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'California', 'lat': '37.80437', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 2643, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': '00', 'lng': '36', 'geonameId': 248816, 'toponymName': 'Hashemite Kingdom of Jordan', 'countryId': '248816', 'fcl': 'A', 'population': 9956011, 'countryCode': 'JO', 'name': 'Jordan', 'fclName': 'country, state, region,...', 'countryName': 'Jordan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 108, 'geonames': [{'adminCode1': '06', 'lng': '35.21633', 'geonameId': 281184, 'toponymName': 'Jerusalem', 'countryId': '294640', 'fcl': 'P', 'population': 971800, 'countryCode': 'IL', 'name': 'Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JM'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Jerusalem', 'lat': '31.76904', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 1332, 'geonames': [{'adminCode1': 'WE', 'lng': '35.23388', 'geonameId': 7303419, 'toponymName': 'East Jerusalem', 'countryId': '6254930', 'fcl': 'P', 'population': 428304, 'countryCode': 'PS', 'name': 'East Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'section of populated place', 'adminName1': 'West Bank', 'lat': '31.78336', 'fcode': 'PPLX'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 357994, 'toponymName': 'Arab Republic of Egypt', 'countryId': '357994', 'fcl': 'A', 'population': 98423595, 'countryCode': 'EG', 'name': 'Egypt', 'fclName': 'country, state, region,...', 'countryName': 'Egypt', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '27', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 22, 'geonames': [{'adminCode1': '00', 'lng': '51.25', 'geonameId': 289688, 'toponymName': 'State of Qatar', 'countryId': '289688', 'fcl': 'A', 'population': 2781677, 'countryCode': 'QA', 'name': 'Qatar', 'fclName': 'country, state, region,...', 'countryName': 'Qatar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 715, 'geonames': [{'adminCode1': '14', 'lng': '101.68653', 'geonameId': 1735161, 'toponymName': 'Kuala Lumpur', 'countryId': '1733045', 'fcl': 'P', 'population': 1453975, 'countryCode': 'MY', 'name': 'Kuala Lumpur', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '14'}, 'countryName': 'Malaysia', 'fcodeName': 'capital of a political entity', 'adminName1': 'Kuala Lumpur', 'lat': '3.1412', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '112.5', 'geonameId': 1733045, 'toponymName': 'Malaysia', 'countryId': '1733045', 'fcl': 'A', 'population': 31528585, 'countryCode': 'MY', 'name': 'Malaysia', 'fclName': 'country, state, region,...', 'countryName': 'Malaysia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '2.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 49, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '00', 'lng': '120', 'geonameId': 1643084, 'toponymName': 'Republic of Indonesia', 'countryId': '1643084', 'fcl': 'A', 'population': 267663435, 'countryCode': 'ID', 'name': 'Indonesia', 'fclName': 'country, state, region,...', 'countryName': 'Indonesia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '04', 'lng': '106.84513', 'geonameId': 1642911, 'toponymName': 'Jakarta', 'countryId': '1643084', 'fcl': 'P', 'population': 8540121, 'countryCode': 'ID', 'name': 'Jakarta', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JK'}, 'countryName': 'Indonesia', 'fcodeName': 'capital of a political entity', 'adminName1': 'Jakarta', 'lat': '-6.21462', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 21, 'geonames': [{'adminCode1': '06', 'lng': '28.04363', 'geonameId': 993800, 'toponymName': 'Johannesburg', 'countryId': '953987', 'fcl': 'P', 'population': 9418183, 'countryCode': 'ZA', 'name': 'Johannesburg', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'GP'}, 'countryName': 'South Africa', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gauteng', 'lat': '-26.20227', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': 'ENG', 'lng': '-0.12574', 'geonameId': 2643743, 'toponymName': 'London', 'countryId': '2635167', 'fcl': 'P', 'population': 8961989, 'countryCode': 'GB', 'name': 'London', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ENG'}, 'countryName': 'United Kingdom', 'fcodeName': 'capital of a political entity', 'adminName1': 'England', 'lat': '51.50853', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 109, 'geonames': [{'adminCode1': '11', 'lng': '2.3488', 'geonameId': 2988507, 'toponymName': 'Paris', 'countryId': '3017382', 'fcl': 'P', 'population': 2138551, 'countryCode': 'FR', 'name': 'Paris', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'capital of a political entity', 'adminName1': 'Île-de-France', 'lat': '48.85341', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 44, 'geonames': [{'adminCode1': '09', 'lng': '16.37208', 'geonameId': 2761369, 'toponymName': 'Vienna', 'countryId': '2782113', 'fcl': 'P', 'population': 1691468, 'countryCode': 'AT', 'name': 'Vienna', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '9'}, 'countryName': 'Austria', 'fcodeName': 'capital of a political entity', 'adminName1': 'Vienna', 'lat': '48.20849', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 210, 'geonames': [{'adminCode1': '16', 'lng': '13.41053', 'geonameId': 2950159, 'toponymName': 'Berlin', 'countryId': '2921044', 'fcl': 'P', 'population': 3426354, 'countryCode': 'DE', 'name': 'Berlin', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BE'}, 'countryName': 'Germany', 'fcodeName': 'capital of a political entity', 'adminName1': 'State of Berlin', 'lat': '52.52437', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 13, 'geonames': [{'adminCode1': '16', 'lng': '35.94503', 'geonameId': 250441, 'toponymName': 'Amman', 'countryId': '248816', 'fcl': 'P', 'population': 1275857, 'countryCode': 'JO', 'name': 'Amman', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AM'}, 'countryName': 'Jordan', 'fcodeName': 'capital of a political entity', 'adminName1': 'Amman', 'lat': '31.95522', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 1582, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 181, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': 'NH', 'lng': '-71.45479', 'geonameId': 5089178, 'toponymName': 'Manchester', 'countryId': '6252001', 'fcl': 'P', 'population': 110229, 'countryCode': 'US', 'name': 'Manchester', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NH'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'New Hampshire', 'lat': '42.99564', 'fcode': 'PPL'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '47.5', 'geonameId': 69543, 'toponymName': 'Republic of Yemen', 'countryId': '69543', 'fcl': 'A', 'population': 28498687, 'countryCode': 'YE', 'name': 'Yemen', 'fclName': 'country, state, region,...', 'countryName': 'Yemen', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '15.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '79', 'geonameId': 1269750, 'toponymName': 'Republic of India', 'countryId': '1269750', 'fcl': 'A', 'population': 1352617328, 'countryCode': 'IN', 'name': 'India', 'fclName': 'country, state, region,...', 'countryName': 'India', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 20, 'geonames': [{'adminCode1': '40', 'lng': '78.45636', 'geonameId': 1269843, 'toponymName': 'Hyderābād', 'countryId': '1269750', 'fcl': 'P', 'population': 6809970, 'countryCode': 'IN', 'name': 'Hyderabad', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TS'}, 'countryName': 'India', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Telangana', 'lat': '17.38405', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 8, 'geonames': [{'lng': '-144.73333', 'geonameId': 6631364, 'toponymName': 'Colombo, Mount', 'countryId': '6697173', 'fcl': 'T', 'population': 0, 'countryCode': 'AQ', 'name': 'Colombo, Mount', 'fclName': 'mountain,hill,rock,... ', 'countryName': 'Antarctica', 'fcodeName': 'mountain', 'adminName1': '', 'lat': '-76.51667', 'fcode': 'MT'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '17', 'geonameId': 3355338, 'toponymName': 'Republic of Namibia', 'countryId': '3355338', 'fcl': 'A', 'population': 2448255, 'countryCode': 'NA', 'name': 'Namibia', 'fclName': 'country, state, region,...', 'countryName': 'Namibia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '10.5', 'geonameId': 2921044, 'toponymName': 'Federal Republic of Germany', 'countryId': '2921044', 'fcl': 'A', 'population': 82927922, 'countryCode': 'DE', 'name': 'Germany', 'fclName': 'country, state, region,...', 'countryName': 'Germany', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '51.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 18, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 18, 'geonames': [{'adminCode1': '00', 'lng': '15', 'geonameId': 2661886, 'toponymName': 'Kingdom of Sweden', 'countryId': '2661886', 'fcl': 'A', 'population': 10183175, 'countryCode': 'SE', 'name': 'Sweden', 'fclName': 'country, state, region,...', 'countryName': 'Sweden', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '62', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 16, 'geonames': [{'adminCode1': '29', 'lng': '57.07879', 'geonameId': 128234, 'toponymName': 'Kerman', 'countryId': '130758', 'fcl': 'P', 'population': 577514, 'countryCode': 'IR', 'name': 'Kerman', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '08'}, 'countryName': 'Iran', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Kerman', 'lat': '30.28321', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': '00', 'lng': '35.83333', 'geonameId': 272103, 'toponymName': 'Lebanon', 'countryId': '272103', 'fcl': 'A', 'population': 6848925, 'countryCode': 'LB', 'name': 'Lebanon', 'fclName': 'country, state, region,...', 'countryName': 'Lebanon', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 80, 'geonames': [{'adminCode1': 'PA', 'lng': '-75.37046', 'geonameId': 5180225, 'toponymName': 'Bethlehem', 'countryId': '6252001', 'fcl': 'P', 'population': 74892, 'countryCode': 'US', 'name': 'Bethlehem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'PA'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Pennsylvania', 'lat': '40.62593', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Nairoukh&username=abdus.salam2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 123, 'geonames': [{'adminCode1': '00', 'lng': '105', 'geonameId': 1814991, 'toponymName': 'People’s Republic of China', 'countryId': '1814991', 'fcl': 'A', 'population': 1411778724, 'countryCode': 'CN', 'name': 'China', 'fclName': 'country, state, region,...', 'countryName': 'China', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '12.83333', 'geonameId': 3175395, 'toponymName': 'Italian Republic', 'countryId': '3175395', 'fcl': 'A', 'population': 60431283, 'countryCode': 'IT', 'name': 'Italy', 'fclName': 'country, state, region,...', 'countryName': 'Italy', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '42.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '-4', 'geonameId': 2510769, 'toponymName': 'Kingdom of Spain', 'countryId': '2510769', 'fcl': 'A', 'population': 46723749, 'countryCode': 'ES', 'name': 'Spain', 'fclName': 'country, state, region,...', 'countryName': 'Spain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '40', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '00', 'lng': '35', 'geonameId': 298795, 'toponymName': 'Republic of Turkey', 'countryId': '298795', 'fcl': 'A', 'population': 82319724, 'countryCode': 'TR', 'name': 'Türkiye', 'fclName': 'country, state, region,...', 'countryName': 'Türkiye', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Shawawra&username=abdus.salam2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '11', 'lng': '-106.41859', 'geonameId': 12822709, 'toponymName': 'Hague', 'countryId': '6251999', 'fcl': 'A', 'population': 0, 'countryCode': 'CA', 'name': 'Hague', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SK'}, 'countryName': 'Canada', 'fcodeName': 'second-order administrative division', 'adminName1': 'Saskatchewan', 'lat': '52.51118', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 287, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.30627', 'geonameId': 281124, 'toponymName': 'Khān Yūnis', 'countryId': '6254930', 'fcl': 'P', 'population': 173183, 'countryCode': 'PS', 'name': 'Khan Yunis', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.34018', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '38', 'geonameId': 163843, 'toponymName': 'Syrian Arab Republic', 'countryId': '163843', 'fcl': 'A', 'population': 16906283, 'countryCode': 'SY', 'name': 'Syria', 'fclName': 'country, state, region,...', 'countryName': 'Syria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Mazzeh&username=abdus.salam2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 43, 'geonames': [{'adminCode1': '13', 'lng': '36.29128', 'geonameId': 170654, 'toponymName': 'Damascus', 'countryId': '163843', 'fcl': 'P', 'population': 1569394, 'countryCode': 'SY', 'name': 'Damascus', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DI'}, 'countryName': 'Syria', 'fcodeName': 'capital of a political entity', 'adminName1': 'Dimashq', 'lat': '33.5102', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Houthis&username=abdus.salam2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1970, 'geonames': [{'adminCode1': '01', 'lng': '-113.802', 'geonameId': 6118158, 'toponymName': 'Red Deer', 'countryId': '6251999', 'fcl': 'P', 'population': 73593, 'countryCode': 'CA', 'name': 'Red Deer', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '52.26682', 'fcode': 'PPL'}]}
# {'totalResultsCount': 12, 'geonames': [{'adminCode1': '09', 'lng': '122.0236', 'geonameId': 1726399, 'toponymName': 'Basilan Strait', 'countryId': '1694008', 'fcl': 'H', 'population': 0, 'countryCode': 'PH', 'name': 'Basilan Strait', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': '09'}, 'countryName': 'Philippines', 'fcodeName': 'strait', 'adminName1': 'Zamboanga Peninsula', 'lat': '6.8127', 'fcode': 'STRT'}]}
# {'totalResultsCount': 234, 'geonames': [{'lng': '48', 'geonameId': 80303, 'name': 'Gulf of Aden', 'fclName': 'stream, lake, ...', 'toponymName': 'Gulf of Aden', 'fcodeName': 'gulf', 'adminName1': '', 'lat': '12', 'fcl': 'H', 'fcode': 'GULF', 'population': 0}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '26', 'lng': '44.20667', 'geonameId': 71137, 'toponymName': 'Sanaa', 'countryId': '69543', 'fcl': 'P', 'population': 1937451, 'countryCode': 'YE', 'name': 'Sanaa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SA'}, 'countryName': 'Yemen', 'fcodeName': 'capital of a political entity', 'adminName1': 'Amanat Alasimah', 'lat': '15.35472', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '08', 'lng': '42.95452', 'geonameId': 79415, 'toponymName': 'Al Ḩudaydah', 'countryId': '69543', 'fcl': 'P', 'population': 617871, 'countryCode': 'YE', 'name': 'Al Hudaydah', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'HU'}, 'countryName': 'Yemen', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Al Hudaydah', 'lat': '14.79781', 'fcode': 'PPLA'}]}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
